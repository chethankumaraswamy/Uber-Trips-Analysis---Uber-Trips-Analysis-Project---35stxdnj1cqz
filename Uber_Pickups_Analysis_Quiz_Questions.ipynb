# %% [markdown]
# ### Uber Pickups Analysis Quiz
#
# The question set is based on the August dataset, `uber-raw-data-aug14.csv`.
#
# #### Keeping the dataset ready before questions

# %%
import pandas as pd

df = pd.read_csv('./data/uber-raw-data-aug14.csv')
df.head()
# Out:
#           Date/Time      Lat      Lon    Base
# 0  8/1/2014 0:03:00  40.7366 -73.9906  B02512
# 1  8/1/2014 0:09:00  40.7260 -73.9918  B02512
# 2  8/1/2014 0:12:00  40.7209 -74.0507  B02512
# 3  8/1/2014 0:12:00  40.7387 -73.9856  B02512
# 4  8/1/2014 0:12:00  40.7323 -74.0077  B02512

# %% [markdown]
# #### Q1. On what date did we see the most number of Uber pickups?
#
# **Skill Test:** Grouping & Counting

# %%
# Convert the 'Date/Time' column to datetime format
df['Date/Time'] = pd.to_datetime(df['Date/Time'])
print(df.dtypes)
# Group by date and count the number of pickups
pickup_counts = df.groupby(df['Date/Time'].dt.date).size()
print(pickup_counts)
# Find the date with the highest number of pickups
date_with_highest_pickups = pickup_counts.idxmax()
print(date_with_highest_pickups)
# Out:
# Date/Time    datetime64[ns]
# Lat                 float64
# Lon                 float64
# Base                 object
# dtype: object
# Date/Time
# 2014-08-01    32353
# 2014-08-02    28678
# 2014-08-03    23146
# 2014-08-04    24952
# 2014-08-05    28094
# 2014-08-06    30495
# 2014-08-07    32759
# 2014-08-08    30411
# 2014-08-09    26286
# 2014-08-10    20584
# 2014-08-11    22632
# 2014-08-12    29646
# 2014-08-13    29788
# 2014-08-14    30457
# 2014-08-15    28974
# 2014-08-16    26234
# 2014-08-17    21209
# 2014-08-18    21956
# 2014-08-19    24834
# 2014-08-20    27955
# 2014-08-21    32304
# 2014-08-22    29512
# 2014-08-23    27097
# 2014-08-24    22036
# 2014-08-25    22093
# 2014-08-26    24550
# 2014-08-27    27018
# 2014-08-28    28597
# 2014-08-29    27424
# 2014-08-30    23930
# 2014-08-31    23271
# dtype: int64
# 2014-08-07

# %% [markdown]
# #### Q.2 How many Uber pickups were made on the date with the highest number of pickups?
#
# **Skill Test:** Indexing and filtering

# %%
# Filter the DataFrame to include only the rows for the date with the highest number of pickups
filtered_df = df[df['Date/Time'].dt.date == date_with_highest_pickups]
print("Filtered DataFrame:")

# Get the count of pickups on the highest date
highest_pickups_count = len(filtered_df)
print(filtered_df)
# Out:
# Filtered DataFrame:
#                  Date/Time      Lat      Lon    Base
# 6944   2014-08-07 00:03:00  40.7455 -73.9895  B02512
# 6945   2014-08-07 00:09:00  40.7499 -74.0025  B02512
# 6946   2014-08-07 00:10:00  40.7417 -74.0037  B02512
# 6947   2014-08-07 00:16:00  40.6416 -73.7879  B02512
# 6948   2014-08-07 00:16:00  40.7008 -73.9405  B02512
# ...                    ...      ...      ...     ...
# 783791 2014-08-07 23:47:00  40.7337 -73.9925  B02764
# 783792 2014-08-07 23:47:00  40.7245 -73.9934  B02764
# 783793 2014-08-07 23:49:00  40.7624 -74.0204  B02764
# 783794 2014-08-07 23:53:00  40.7801 -73.9589  B02764
# 783795 2014-08-07 23:54:00  40.7648 -73.9783  B02764
#
# [32759 rows x 4 columns]

# %% [markdown]
# #### Q.3 How many unique TLC base companies are affiliated with the Uber pickups in the dataset?
#
# **Skill Test:** Counting unique values

# %%
# Count the number of unique TLC base companies
unique_base_companies = df.nunique()

# Print the result
print(unique_base_companies)
# Out:
# Date/Time    44432
# Lat           5289
# Lon           7629
# Base             5
# dtype: int64

# %% [markdown]
# #### Q.4 Which TLC base company had the highest number of pickups?
#
# **Skill Test:** Grouping, counting, and finding the maximum

# %%
# TLC base compGroup by any and count number of pickups


# Find the TLC base company with the highest number of pickups
company_with_highest_pickups = pickup_counts.idxmax()

# Print the result
print(company_with_highest_pickups)
# Out:
# 2014-08-07

# %% [markdown]
# #### Q.5 How many Uber pickups were made at each unique TLC base company?
#
# **Skill Test:** Grouping and counting

# %%
# Group by TLC base company and count number of pickups

# %% [markdown]
# #### Q.6 Can you determine the busiest time of day for Uber pickups based on the date/time column?
#
# **Skill Test:** Extracting time components, grouping, counting, and finding the maximum

# %%
# Extract the hour from the 'Date/Time' column
df['Hour'] = df['Date/Time'].dt.hour

# Group by hour and count number of pickups
pickup_counts = df.groupby('Hour').size()

# Find the hour with the highest number of pickups
hour_with_highest_pickups = pickup_counts.idxmax()

# Print the result
print(hour_with_highest_pickups)
# Out:
# 17

# %% [markdown]
# #### Q.7 Can you create a visualization (e.g., a bar chart or line plot) to represent the number of Uber pickups over time?
#
# **Skill Test:** Data Visualization using Plotting function

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.7.1-cp311-cp311-win_amd64.whl (7.6 MB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.0.7-cp311-cp311-win_amd64.whl (162 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\chethan k\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\chethan k\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\chethan k\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\chethan k\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\chethan k\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\chethan k\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\chethan k\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\chethan k\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: cycler, contourpy, matplotlib
# Successfully installed contourpy-1.0.7 cycler-0.11.0 matplotlib-3.7.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
# Group by date and count number of pickups
pickup_counts = df.groupby(df['Date/Time'].dt.date).size()

# Create a line plot
plt.plot(pickup_counts.index, pickup_counts.values)
plt.xlabel('Date')
plt.ylabel('Number of Pickups')
plt.title('Number of Pickups Over Time')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Q8. Can you create a scatter plot to visualize the distribution of Uber pickups based on latitude and longitude?
#
# **Skill Test:** Scatter Plot

# %%
# Create a scatter plot to visualize the distribution of Uber pickups based on latitude and longitude

# %% [markdown]
# #### Q9. Can you create a bar chart to compare the number of Uber pickups for each TLC base company?
#
# **Skill Test:** Bar Chart

# %%
# Create a bar chart to compare the number of Uber pickups for each TLC base company
plt.bar(pickup_counts.index, pickup_counts.values)
plt.xlabel('TLC Base Company')
plt.ylabel('Number of Pickups')
plt.title('Number of Uber Pickups by TLC Base Company')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Q10. Can you create a pie chart to display the percentage distribution of Uber pickups for each day of the week?
#
# **Skill Test:** Pie Chart

# %%
# Group by day of the week and count the number of pickups
pickup_counts = df['Date/Time'].dt.day_name().value_counts()

# Create a pie chart to display the percentage distribution of Uber pickups for each day of the week
plt.pie(pickup_counts.values, labels=pickup_counts.index, autopct='%1.1f%%')
plt.title('Percentage Distribution of Uber Pickups by Day of the Week')
plt.axis('equal')
plt.show()
